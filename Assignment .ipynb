# %% [markdown]
# ## 1. What exactly is []?

# %% [markdown]
#  The empty list value, which is a list value that contains no items. This is similar to how '' is the empty string value.

# %% [markdown]
# ## 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %%
k=[2,4,6,8,10]

# %%
k.insert(3,"hello")

# %%
k
# Out:
# [2, 4, 6, 'hello', 8, 10]

# %% [markdown]
# ## Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.

# %%
spam=['a', 'b', 'c', 'd']

# %% [markdown]
# ## 3. What is the value of spam[int(int('3' * 2) / 11)]?

# %%
spam[int(int('3' * 2) / 11)]
# Out:
# 'd'

# %% [markdown]
# ## 4. What is the value of spam[-1]?

# %%
spam[-1]
# Out:
# 'd'

# %% [markdown]
# ## 5. What is the value of spam[:2]?

# %%
spam[:2]
# Out:
# ['a', 'b']

# %% [markdown]
# ## Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.

# %%
bacon=[3.14, 'cat',11, 'cat', True]

# %% [markdown]
# ## 6. What is the value of bacon.index('cat')?

# %%
bacon.index('cat')
# Out:
# 1

# %% [markdown]
# ## 7. How does bacon.append(99) change the look of the list value in bacon?

# %%
bacon.append(99)

# %%
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# ## 8. How does bacon.remove('cat') change the look of the list in bacon?

# %%
bacon.remove('cat')

# %%
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# # 9. What are the list concatenation and list replication operators

# %% [markdown]
# ## list concatenation = +

# %%
a=[1,2,3]

# %%
b=[2,34,546,"poras"]

# %%
c=a+b
c
# Out:
# [1, 2, 3, 2, 34, 546, 'poras']

# %% [markdown]
# ## list replication = *

# %%
a=[1,2,3]

# %%
b=[2,34,546,"poras"]

# %%
c=a*3

# %%
c
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
d=b*2

# %%
d
# Out:
# [2, 34, 546, 'poras', 2, 34, 546, 'poras']

# %% [markdown]
# ## 10. What is difference between the list methods append() and insert()?

# %% [markdown]
# ### append()

# %% [markdown]
# #### The append() method appends an element to the end of the list

# %% [markdown]
# ###### note -- It appends only elements it wont append any iterables in the list that is doen by extend command

# %% [markdown]
# ### insert()

# %% [markdown]
# ####  insert a list item at a specified index, use the insert() method

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(1, "orange")
print(thislist)
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %% [markdown]
# ## 11. What are the two methods for removing items from a list?

# %% [markdown]
# #### The remove() method removes the specified item.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# ### The pop() method removes the specified index.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop()
print(thislist)
# Out:
# ['apple', 'banana']

# %% [markdown]
# ## 12. Describe how list values and string values are identical?

# %% [markdown]
# ### 1.Both strings and lists have lengths

# %% [markdown]
# #### a string's length is the number of characters in the string;
# #### a list's length is the number of items in the list. x

# %% [markdown]
# ### 2.Each character in a string as well as each item in a list has a position, also called an index.

# %% [markdown]
# ## 13. What's the difference between tuples and lists?

# %% [markdown]
# ![python-tuples-vs-lists.jpg](attachment:python-tuples-vs-lists.jpg)

# %% [markdown]
# ## major differnece is about the function of mutability

# %% [markdown]
# ## 14. How do you type a tuple value that only contains the integer 42?

# %%
t=(42,)

# %%
for i in t:
    print(i)
# Out:
# 42

# %% [markdown]
# ### Here the comma is mandatory otherwise it will try to iterate thrugh interger 42 which wil give error

# %% [markdown]
# ## 15. How do you get a list value's tuple form? How do you get a tuple value's list form?

# %% [markdown]
# The tuple() and list() functions, respectively

# %% [markdown]
# ## 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

# %% [markdown]
# They contain references to list values

# %% [markdown]
# ## 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %% [markdown]
# The copy.copy() function will do a shallow copy of a list, while the copy.deepcopy() function will do a deep copy of a list. That is, only copy.deepcopy() will duplicate any lists inside the list.
